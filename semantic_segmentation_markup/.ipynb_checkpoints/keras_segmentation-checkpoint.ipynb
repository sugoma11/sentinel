# %%
import tensorflow as tf
import cv2
# Out:
# 2023-03-24 11:47:35.610155: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-24 11:47:35.701139: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-24 11:47:36.244705: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/alex/miniconda3/envs/nns/lib/
# ...

# %%
tf.config.list_physical_devices('GPU')
# Out:
# 2023-03-24 11:47:39.705978: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2023-03-24 11:47:39.722737: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-24 11:47:39.723328: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
import os
 
from keras_segmentation.pretrained import pspnet_50_ADE_20K , pspnet_101_cityscapes, pspnet_101_voc12

# %%
keras_segmentation.__file__

# %%
import keras
keras.__version__
# Out:
# '2.11.0'

# %%
model = pspnet_101_voc12()
# Out:
# 2023-03-24 11:48:05.403425: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-24 11:48:05.408911: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-24 11:48:05.409895: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
out = model.predict_segmentation(
    inp="1_input.jpg",
    out_fname="./out.png"
)
# Out:
# [ WARN:0@36.297] global loadsave.cpp:244 findDecoder imread_('1_input.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 out = model.predict_segmentation(
#       2     inp="1_input.jpg",
#       3     out_fname="./out.png"
#       4 )
#
# File ~/miniconda3/envs/nns/lib/python3.10/site-packages/keras_segmentation/predict.py:142, in predict(model, inp, out_fname, checkpoints_path, overlay_img, class_names, show_legends, colors, prediction_width, prediction_height)
#     139 if isinstance(inp, six.string_types):
#     140     inp = cv2.imread(inp)
# --> 142 assert len(inp.shape) == 3, "Image should be h,w,3 "
#     144 output_width = model.output_width
#     145 output_height = model.output_height
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
out = model.predict_segmentation(
    inp="dataset2/images_prepped_test/2017-09-21-00_00_2017-09-21-23_59_Sentinel-2_L2A_True_color.png",
    out_fname="/tmp/out.png"
)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
import matplotlib.pyplot as plt
plt.imshow(out)

# %%
im = cv2.imread('2018-06-28-00_00_2018-06-28-23_59_Sentinel-2_L2A_True_color.png')
im.shape[0], im.shape[1]
# Out:
# (766, 1920)

# %%
from keras_segmentation.models.unet import vgg_unet

model = vgg_unet(n_classes=6)

model.train(
    train_images =  "dataset2/images_prepped_train/",
    train_annotations = "dataset2/annotations_prepped_train/",
    checkpoints_path = "./vgg_unet_1" , epochs=5
)
# Out:
# Verifying training dataset
# 100%|████████████████████████████████████████████████████████████████████████████████| 115/115 [00:04<00:00, 24.15it/s]
# E:\conda\envs\nns\lib\site-packages\keras_segmentation\train.py:156: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_gen, steps_per_epoch,
# Dataset verified!
# Epoch 1/5
# ...
# 512/512 [==============================] - 148s 276ms/step - loss: 2.1658 - accuracy: 0.2633
# Epoch 2/5
# ...
# 512/512 [==============================] - 141s 275ms/step - loss: 1.5793 - accuracy: 0.4859
# Epoch 3/5
# ...
# 512/512 [==============================] - 141s 275ms/step - loss: 1.2727 - accuracy: 0.6113
# Epoch 4/5
# ...
# 512/512 [==============================] - 141s 276ms/step - loss: 1.0578 - accuracy: 0.7035
# Epoch 5/5
# ...
# 512/512 [==============================] - 141s 276ms/step - loss: 0.8909 - accuracy: 0.7694

# %%
from keras.backend import clear_session

# %%
out = model.predict_segmentation(
    inp="dataset2/images_prepped_test/2018-09-13-00_00_2018-09-13-23_59_Sentinel-2_L2A_True_color.png",
    out_fname="./out.png"
)
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
clear_session()

# %%
del model
